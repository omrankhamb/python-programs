# %%
print("Hello World")
a,b = map(int,(input("EEnter number : ").split()))
print(a,b)
# Out:
# Hello World
# 1 2

# %%
c = [1,2,3,4,5,6,7,8]
lLis = list(filter(lambda x : x % 2== 0 ,c))
print(lLis)
# Out:
# [2, 4, 6, 8]

# %%
str = input("eNTER STRING : ")
lis= str.split()
print(lis)
str = ''.join(lis)
print(str)
# Out:
# ['efwlk', 'svs']
# efwlksvs
